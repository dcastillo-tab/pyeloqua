# %%
from pyeloqua import bulk
import pymysql

# %%
# set up a "session" with our Eloqua instance
bulker = bulk.Bulk(company='', username='', password='')

# %%
# fields = bulker.GetFields('contacts')

# %%
# field_set = []
# for field in fields:
#     field_set.append(field['internalName'])

# %%
# field_set = ['C_EmailAddress',
#             'C_Account_Type1',
#             'C_Address1',
#             'C_adgroup1',
#             'C_Adused1',
#             'C_Annual_Revenue1',
#             'C_Audience1',
#             'C_Authorized_User_Check_on_Contact1',
#             'C_Browser_Language___Most_Recent1',
#             'C_BusPhone',
#             'C_Buy_Registration_Date___Most_Recent1',
#             'C_Campaign_ID___Most_Recent1',
#             'C_Campaign_ID___Original1',
#             'C_CASL_EBR_Eval___Customer1',
#             'C_CASL_EBR_Eval___Online_Trial1',
#             'C_CASL_EBR_Eval___Opp1',
#             'C_CASL_EBR_Eval___Prod_Reg1',
#             'C_CASL_EBR_Evaluation1',
#             'C_City',
#             'C_Click_ID1',
#             'C_Company',
#             'C_Country',
#             'C_Customer1',
#             'C_Customer_Date1',
#             'C_DateCreated',
#             'C_DateModified',
#             'C_db_annual_sales1',
#             'C_db_country1',
#             'C_db_employee_count1',
#             'C_db_industry1',
#             'C_db_sic1',
#             'C_db_state1',
#             'C_db_sub_industry1',
#             'C_db_title1',
#             'C_db_web_site1',
#             'C_db_zip1',
#             'C_Dept1',
#             'C_Device1',
#             'ContactIDExt',
#             'C_Eloqua_Program1',
#             'C_Eloqua_Slice_Score1',
#             'C_EmailAddressDomain',
#             'C_FirstName',
#             'C_GCLID1',
#             'C_Highest_Stage1',
#             'C_Industry1',
#             'C_job_level1',
#             'C_Keyword1',
#             'C_Language_Site___Most_Recent1',
#             'C_LastName',
#             'C_Lead_Source___Most_Recent1',
#             'C_Lead_Source___Original1',
#             'C_Lead_Source_Detail___Most_Recent1',
#             'C_Lead_Source_Detail___Original1',
#             'C_Lead_Stage1',
#             'C_Lead_Status1',
#             'C_Lead_Type1',
#             'C_Marketing_GUID1',
#             'C_Marketing_Opt_Out___For_Harvested_Names1',
#             'C_Matchype1',
#             'C_MobilePhone',
#             'C_Name_Analyzer___Gender_Results1',
#             'C_Name_Analyzer___Validation_Results1',
#             'C_Online_Trial_Exp_Date___Most_Recent1',
#             'C_Online_Trial_Start_Date1',
#             'C_Online__Admin_Date1',
#             'C_Online__Days_Since_Last_Login1',
#             'C_Online__Is_Customer1',
#             'C_Online__Last_Activity_Date1',
#             'C_Online__Most_Recent_Login1',
#             'C_Online__Site_Count1',
#             'C_Online__Site_Suspension_Date1',
#             'C_Online__Total_Publishes1',
#             'C_CASL_Approval1',
#             'C_Opt_in_Date1',
#             'C_Placement1',
#             'C_Platform1',
#             'C_Supported_Language1',
#             'C_Primed_Date1',
#             'C_Promo_Campaign_Original1',
#             'C_Promo_Country_Original1',
#             'C_Promo_Language1',
#             'C_Promo_Medium_Original1',
#             'C_Promo_Source_Original1',
#             'C_Qualifying_Date1',
#             'C_Reason_Primed___Most_Recent1',
#             'C_Remarket_Date1',
#             'C_Salesperson',
#             'C_Salesperson_Email1',
#             'C_Salutation',
#             'C_Segment1',
#             'C_Server_Trial_Start_Date1',
#             'C_Server_Trial_End_Date1',
#             'C_SFDC_Date_Created1',
#             'C_SFDC_EmailOptOut1',
#             'C_SFDCAccountID',
#             'C_SFDCContactID',
#             'C_SFDCLeadID',
#             'C_Territory_ID1',
#             'C_Slice_Score1',
#             'C_Slice_Score___Enterprise1',
#             'C_State_Prov',
#             'C_TQL_Date1',
#             'C_Trial_Exp_Date1',
#             'C_Trial_Product___Most_Recent1',
#             'C_Trial_Request1',
#             'C_Trial_Start_Date1',
#             'C_Zip_Postal',
#             'C_GACLIENTID1',
#             'C_tableau_id1',
#             'C_Territory_Model1',
#             'C_6sense_Contact_Intent_Score1',
#             'C_6sense_Contact_Profile_Score1',
#             'C_6sense_Account_Intent_Score1',
#             'C_6sense_Account_Profile_Score1',
#             'C_is_deleted1',
#             'C_Deleted_Date1',
#             'C_eCommerce_Date1',
#             'C_eCommerce_Date___Original1',
#             'C_Company_Size1',
#             'C_Lead_Owner_ID1',
#             'C_Tableau_Prep_Trial_Start_Date1',
#             'C_Tableau_Prep_Trial_Exp_Date1',
#             'C_Customer_Churned_Date1',
#             'C_SFDC_Lead_Rating1',
#             'C_Ford_Opt_Out1',
#             'C_Salesforce_Date_Passed1',
#             'C_Salesforce_Opt_in1',
#             'C_Salesforce_Opt_in_Date1',
#             'C_Salesforce_Opt_Out1',
#             'C_Salesforce_Opt_Out_Date1',
#             'C_Remarket_Reason1',
#             'C_SIC_Code1',
#             'C_6sense_Last_Modified_Date1',
#             'C_Title',
#             'C_Persona1',
#             'C_Synthio_Last_Modified_Date1',
#             'C_Email_Suppression1',
#             'C_Email_Suppression___First_Registration_Date',
#             'C_Email_Suppression_Detail1',
#             'C_Customer_Lifecycle_Stage1',
#             'C_6sense_Contact_Profile_Score___Original1']

# %%
# specify that we want an export of contact records:
bulker.exports('contacts')

# %%
field_set = ['C_EmailAddress', 'ContactIDExt', 'C_is_deleted1']

# %%
bulker.add_fields(field_set)

# %%
# bulker.filter_date('C_DateCreated', '2020-12-01 0:00:00', '2020-12-05 0:00:00')

# %%
bulker.create_def('contact export')

# %%
bulker.sync(timeout=100000) # creates a sync which tells Eloqua to prepare the data
# Out:
# 'success'

# %%
bulker.get_export_data('./elq_contacts.csv', offset=50000, threads=True) # retrieve the prepared data
# Out:
# https://secure.p01.eloqua.com/API/Bulk/2.0//contacts/exports/11487175/data?limit=50000&offset=0
# https://secure.p01.eloqua.com/API/Bulk/2.0//contacts/exports/11487175/data?limit=50000&offset=100000
# https://secure.p01.eloqua.com/API/Bulk/2.0//contacts/exports/11487175/data?limit=50000&offset=50000
# https://secure.p01.eloqua.com/API/Bulk/2.0//contacts/exports/11487175/data?limit=50000&offset=150000
# https://secure.p01.eloqua.com/API/Bulk/2.0//contacts/exports/11487175/data?limit=50000&offset=250000
# https://secure.p01.eloqua.com/API/Bulk/2.0//contacts/exports/11487175/data?limit=50000&offset=300000
# https://secure.p01.eloqua.com/API/Bulk/2.0//contacts/exports/11487175/data?limit=50000&offset=200000
# https://secure.p01.eloqua.com/API/Bulk/2.0//contacts/exports/11487175/data?limit=50000&offset=450000
# https://secure.p01.eloqua.com/API/Bulk/2.0//contacts/exports/11487175/data?limit=50000&offset=350000
# ...

# %%
len(contact_records)

# %%
contact_records[0]

# %%
def csv_to_mysql(load_sql, host, user, pw):
    try:
        con = pymysql.connect(host=host, user=user, password=pw,
                             autocommit=True, local_infile=1)
        print('Connected to DB: {}'.format(host))
    
        cursor = con.cursor()
        cursor.execute(load_sql)
        print('Successfully loaded csv into mysql table')
        con.close()
    except Exception as e:
        print('Error: {}'.format(str(e)))
        sys.exit(1)

# %%
path = ''
table = 'pedigree.elq_contacts2'

# %%
load_sql = "LOAD DATA LOCAL INFILE '{}' \
            INTO TABLE {} FIELDS TERMINATED BY ',' ENCLOSED BY '\"' IGNORE 1 LINES;".format(path, table)
host = '104.197.200.172'
user = ''
pw = ''

# %%
csv_to_mysql(load_sql, host, user, pw)
# Out:
# Connected to DB: 104.197.200.172
# Successfully loaded csv into mysql table
